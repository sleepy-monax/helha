# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import KFold, cross_val_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import euclidean_distances, mean_squared_error

# %matplotlib inline

# %%
PATH_S = 'simpsons_episodes.csv'

# %%
sim = pd.read_csv(PATH_S)

# %%
sim
# Out:
#       id                                              title original_air_date  \
# 0     10                                  Homer's Night Out        1990-03-25
# 1     12                                 Krusty Gets Busted        1990-04-29
# 2     14                                   Bart Gets an "F"        1990-10-11
# 3     17  Two Cars in Every Garage and Three Eyes on Eve...        1990-11-01
# 4     19                               Dead Putting Society        1990-11-15
# 5     21                                 Bart the Daredevil        1990-12-06
# 6     23                             Bart Gets Hit by a Car        1991-01-10
# 7     26             Homer vs. Lisa and the 8th Commandment        1991-02-07
# 8     28                        Oh Brother, Where Art Thou?        1991-02-21
# 9     30                                          Old Money        1991-03-28
# 10    32                                  Lisa's Substitute        1991-04-25
# ...

# %%
# il y a quelques lignes où se trouvent des informations nulles => nous les supprimons
sim.dropna(inplace=True)

# %%
# sce signifie scenario
features_sce_1 = ['us_viewers_in_millions', 'views', 'imdb_votes']
features_sce_2 = ['us_viewers_in_millions', 'imdb_votes']

n_neighbors_sce_1 = 10
n_neighbors_sce_2 = 15

# %% [markdown]
# Ligne de conduite a appliquer

# %%
# Point n°2 calcul du MSE
def cross_val_score(data, name_Y):
    ((data[name_Y] - data['hat_' + name_Y])**2).mean()
cross_val_score(sim,'title')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'hat_title'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-36b9217d8d39> in <module>
#       2 def cross_val_score(data, name_Y):
# ...
